# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
from scipy import mean
import statistics
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-213-ef39009d6a4b> in <module>()
#       4 import scipy.stats as sts
#       5 from scipy import mean
# ----> 6 import statistics
#       7 get_ipython().magic(u'matplotlib inline')
#
# ImportError: No module named statistics

# %% [markdown]
# # Равномерное распределение (от 2 до 4)

# %%
a=2
b=4
uniform_rv=sts.uniform(a,b-a)
uniform_rv.rvs(10)
# Out:
# array([2.98051954, 3.05038243, 2.81996092, 3.93195503, 2.00198616,
#        3.68172272, 3.69851508, 3.87079388, 3.29294388, 2.19859783])

# %% [markdown]
# плотность распределения

# %%
x = np.linspace(0,6,100)
pdf = uniform_rv.pdf(x)
plt.plot(x, pdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
# Out:
# Text(0.5,0,'$x$')

# %% [markdown]
# функция распределения

# %%
x = np.linspace(0,6,100)
cdf = uniform_rv.cdf(x)
plt.plot(x, cdf)

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
# Out:
# Text(0.5,0,'$x$')

# %%
sample = uniform_rv.rvs(1000)

# %%
plt.hist(sample, bins=30)
plt.ylabel('fraction of samples')
plt.xlabel('$x$')
# Out:
# Text(0.5,0,'$x$')

# %%
x = np.linspace(0,6,100)
pdf = uniform_rv.pdf(x)
plt.plot(x, pdf, label='theoretical PDF')

plt.hist(sample, bins=30,normed=True, label='theoretical PDF')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# # Распределеня выборочного среднего n=5

# %%
n=5
sr=[]

# %%
for i in range(1000):
    sample = uniform_rv.rvs(n)
    sr.append(mean(sample))

# %%
plt.hist(sr, bins=30,normed=True, label='the distribution of the average n=5')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# # Оценка среднего и дисперсии распределения среднего n=5

# %%
#среднее
m=uniform_rv.mean()
#дисперсия
d=uniform_rv.std()/n
std=d**0.5

# %%
print(m,std)
# Out:
# (3.0, 0.3398088489694245)

# %%
#выборочное стандартное отклонение и среднее
print(np.array(sr).mean())
print(np.array(sr).std())
# Out:
# 2.9831428864434955
# 0.2550523335275703

# %%
#нормальное распредление
norm_rv = sts.norm(m,std)

# %%
plt.hist(sr, bins=30,normed=True, label='the distribution of the average n=5')

x = np.linspace(0,6,1000)
cdf = norm_rv.pdf(x)
plt.plot(x, cdf, label='norm')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# # Распределеня выборочного среднего n=10

# %%
n=10
sr1=[]

# %%
for i in range(1000):
    sample = uniform_rv.rvs(n)
    sr1.append(mean(sample))

# %%
plt.hist(sr1, bins=30,normed=True, label='the distribution of the average n=10')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# # Оценка среднего и дисперсии распределения среднего n=10

# %%
#среднее
m=uniform_rv.mean()
#дисперсия
d=uniform_rv.std()/n
std=d**0.5

# %%
print(m,std)
# Out:
# (3.0, 0.24028114141347542)

# %%
#выборочное стандартное отклонение и среднее
print(np.array(sr1).mean())
print(np.array(sr1).std())
# Out:
# 3.001159238879988
# 0.1808202452703907

# %%
#нормальное распредление
norm_rv = sts.norm(m,std)

# %%
plt.hist(sr1, bins=30,normed=True, label='the distribution of the average n=5')

x = np.linspace(0,6,1000)
cdf = norm_rv.pdf(x)
plt.plot(x, cdf, label='norm')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# # Распределеня выборочного среднего n=15

# %%
n=15
sr2=[]

# %%
for i in range(1000):
    sample = uniform_rv.rvs(n)
    sr2.append(mean(sample))

# %%
plt.hist(sr2, bins=30,normed=True, label='the distribution of the average n=15')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# # Оценка среднего и дисперсии распределения среднего n=15

# %%
#среднее
m=uniform_rv.mean()
#дисперсия
d=uniform_rv.std()/n
std=d**0.5

# %%
print(m,std)
# Out:
# (3.0, 0.19618873042551413)

# %%
#выборочное стандартное отклонение и среднее
print(np.array(sr2).mean())
print(np.array(sr2).std())
# Out:
# 2.9940264773731813
# 0.1430357844545598

# %%
#нормальное распредление
norm_rv = sts.norm(m,std)

# %%
plt.hist(sr2, bins=30,normed=True, label='the distribution of the average n=15')

x = np.linspace(0,6,1000)
cdf = norm_rv.pdf(x)
plt.plot(x, cdf, label='norm')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# # Гистограммы распределений средних

# %%
plt.hist(sr, bins=30,normed=True, label='the distribution of the average n=5')
plt.hist(sr1, bins=30,normed=True, label='the distribution of the average n=10')
plt.hist(sr2, bins=30,normed=True, label='the distribution of the average n=10')

plt.ylabel('$f(x)$')
plt.xlabel('$x$')
plt.legend(loc='upper left')

# %% [markdown]
# # Распределение выборочных средних хорошо апроксимируется нормальным распределением с матожиданием
# # начального распределения и диспесией/n.
# # С увеличением n происходит сжатие распредления (уменьшается дисперсия)
